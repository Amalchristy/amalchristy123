# %% [markdown]
# # Welcome to Jupyter!

# %%
import pandas as pd

df = pd.read_csv(r'weatherrr.csv')
df.head()
# df.sort_values("year").head()
# Add month-day column so we can find record breaking days from 2015

dtype: object

df.dtypes

df["Fires"] = pd.to_numeric(df["Fires"])
df["Acres"] = pd.to_numeric(df["Acres"])
fires = df["Fires"]
acres = df["Acres"]

df.corr()

# np.corrcoef(df["Fires"], df["Acres"] )

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(fires, acres)

plt.xlabel("Fires")
plt.ylabel("Acres (In Crores)")
plt.title("Correlation between Fires and Acres")

plt.show()

#Part2 question
import pandas as pd

df = pd.read_csv(r'weatherrr.csv')
df.head()
df.sort_values("Year").head()

dtype: object

df.dtypes

# df["Fires"] = df.mean(axis=1)
# df["Acres"] = df.mean(axis=1)
df["Fires"] = pd.to_numeric(df["Fires"])
df["Acres"] = pd.to_numeric(df["Acres"])
df_fires = df["Fires"]
df_acres = df["Acres"]
years = df["Year"]

# set year column as index
df.set_index('Year', inplace=True)

# translate index name into English
df.index.name = 'Year'

import matplotlib.pyplot as pltt

pltt.style.use('seaborn')

df['SMAF_5'] = df["Fires"].rolling(5, min_periods=1).mean()

#df_acres['SMA_5'] = df_acres.rolling(5, min_periods=1).mean()

colors = ['green', 'red']
df_fires = df.reindex(columns=['Fires', 'SMAF_5'])

# line plot -
df_fires.plot(color=colors, linewidth=6, figsize=(12,6))

# modify ticks size
pltt.xticks(fontsize=14)
pltt.yticks(fontsize=14)
pltt.legend(labels =['yearly Fires', '5-years moving average of fires'], fontsize=14)

pltt.title('The moving average of Fires', fontsize=20)
pltt.xlabel('Year', fontsize=16)
pltt.ylabel('Fires', fontsize=16)

# plot acres
import matplotlib.pyplot as pltta

pltta.style.use('seaborn')

df['SMAA_5'] = df["Acres"].rolling(5, min_periods=1).mean()

#df_acres['SMA_5'] = df_acres.rolling(5, min_periods=1).mean()

colors = ['blue', 'yellow']
df_acres = df.reindex(columns=['Acres', 'SMAA_5'])

# line plot -
df_acres.plot(color=colors, linewidth=6, figsize=(12,6))

# modify ticks size
pltta.xticks(fontsize=14)
pltta.yticks(fontsize=14)
pltta.legend(labels =['yearly Acres', '5-years moving average of Acres'], fontsize=14)

pltta.title('The moving average of Acres', fontsize=20)
pltta.xlabel('Year', fontsize=16)
pltta.ylabel('Acres', fontsize=16)


# import libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
df = pd.read_csv(r'weatherrr.csv')
df.head()
df.sort_values("Year").head()

df=df[df['Year'] >= 1987]
years = df["Year"]
colors= ['blue', 'yellow','red']
# Creating dataset
# x = np.arange(1.0, 100.0, 0.191)
dataset_1 = df['Fires']
dataset_2 = df['Acres']
# Creating plot with dataset_1
fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_xlabel('Years')
ax1.set_ylabel('Fires', color = color)
ax1.plot(years , dataset_1, color = color)
ax1.tick_params(axis ='y', labelcolor = color)

# Adding Twin Axes to plot using dataset_2
ax2 = ax1.twinx()

color = 'tab:green'
ax2.set_ylabel('Acres(in crores)', color = color)
ax2.plot(years , dataset_2, color = color)
ax2.tick_params(axis ='y', labelcolor = color)

# Adding title
plt.title('RELATIONSHIP BETWEEN FIRES AND ACRES', fontweight ="bold")
# Show plot
plt.show()

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook
